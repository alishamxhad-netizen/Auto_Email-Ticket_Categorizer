# %%
print("hello")
# Out:
# hello

# %%
a = int(input("enter a number"))
b = int(input("enter another number"))
if a>b:
    print("a is greater")
else: 
    print("a is average")
# Out:
# a is greater

# %%
import pandas as pd
df = pd.read_excel(r"C:\Academic\framingham.xlsx")

# %%
data.head
# Out:
# <bound method NDFrame.head of       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
# 4238     1   40        3.0              0         0.0     0.0
# 4239     0   39        3.0              1        30.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
data.shape
# Out:
# (4240, 16)

# %%
data.dtypes
# Out:
# male                 int64
# age                  int64
# education          float64
# currentSmoker        int64
# cigsPerDay         float64
# BPMeds             float64
# prevalentStroke      int64
# prevalentHyp         int64
# diabetes             int64
# totChol            float64
# sysBP              float64
# diaBP              float64
# BMI                float64
# heartRate          float64
# glucose            float64
# TenYearCHD           int64
# dtype: object

# %%
data.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
null_value_per_row = data.isnull().any(axis=1).sum()
print(f"total number of null values per column:{null_value_per_row}\n")
# Out:
# total number of null values per column:582

# %%
print("Null values per column:\n")
for col, count in data.isnull().sum().items():
    print(f"{col}: {count}")
# Out:
# Null values per column:
#
# male: 0
# age: 0
# education: 105
# currentSmoker: 0
# cigsPerDay: 29
# BPMeds: 53
# prevalentStroke: 0
# prevalentHyp: 0
# diabetes: 0
# totChol: 50
# sysBP: 0
# diaBP: 0
# BMI: 19
# heartRate: 1
# glucose: 388
# TenYearCHD: 0

# %%
import matplotlib.pyplot as plt
import numpy as np

# Replace df with your dataframe name
columns = df.columns
n_cols = 3  # number of columns per row
n_rows = int(np.ceil(len(columns) / n_cols))

plt.figure(figsize=(18, 4 * n_rows))

for i, col in enumerate(columns, 1):
    # Filter non-null & non-zero values
    data = df[col]
    data = data[(data.notnull()) & (data != 0)]

    plt.subplot(n_rows, n_cols, i)

    # Numeric columns -> histogram
    if np.issubdtype(data.dtype, np.number):
        plt.hist(data, bins=30)
        plt.title(col)
        plt.xlabel("Value")
        plt.ylabel("Frequency")

    # Categorical columns -> bar plot
    else:
        data.value_counts().plot(kind="bar")
        plt.title(col)
        plt.xlabel("Category")
        plt.ylabel("Count")

plt.tight_layout()
plt.show()
